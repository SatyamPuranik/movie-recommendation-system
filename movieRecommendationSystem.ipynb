# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies.head()
movies.columns.values
movies = movies[['id','title','genres','keywords','overview','tagline']]
movies.head()
movies.isna().sum()
# Out:
# id            0
# title         0
# genres        0
# keywords      0
# overview      3
# tagline     844
# dtype: int64

# %%
credits.head()
credits.rename(columns={'movie_id':'id'},inplace=True)
credits.drop(columns='title',inplace =True)
credits.head()
# Out:
#        id                                               cast  \
# 0   19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 1     285  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  206647  [{"cast_id": 1, "character": "James Bond", "cr...
# 3   49026  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4   49529  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies.shape
# Out:
# (4803, 6)

# %%
credits.shape
# Out:
# (4803, 3)

# %%
df = movies.merge(credits,on='id')
df.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
# ...

# %%
df.loc[df['tagline'].isna(),'tagline'] = ''
df.loc[df['overview'].isna(),'overview'] = ''
df.isna().sum()
# Out:
# id          0
# title       0
# genres      0
# keywords    0
# overview    0
# tagline     0
# cast        0
# crew        0
# dtype: int64

# %%
import ast
def convert(obj) -> list:
    L =[]
    for i in ast.literal_eval(obj):
         L.append(i['name'])
    return ' '.join(L)

# %%
df.genres = df.genres.apply(convert)
df.keywords = df.keywords.apply(convert)
df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                         genres  \
# 0     Action Adventure Fantasy Science Fiction
# 1                     Adventure Fantasy Action
# 2                       Action Adventure Crime
# 3                  Action Crime Drama Thriller
# 4             Action Adventure Science Fiction
# ...

# %%
def director(obj):
    for i in ast.literal_eval(obj):
        if i['job'] == 'Director':
            return i['name']
    return ''

def actors(obj):
    L =[]
    for i in ast.literal_eval(obj):
        if len(L) >=3:
            break
        else:
         L.append(i['name'])
    return ' '.join(L)

# %%
df.cast = df['cast'].apply(actors)
df.crew = df.crew.apply(director)
df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                         genres  \
# 0     Action Adventure Fantasy Science Fiction
# 1                     Adventure Fantasy Action
# 2                       Action Adventure Crime
# 3                  Action Crime Drama Thriller
# 4             Action Adventure Science Fiction
# ...

# %%
df = df[['id','title','overview','tagline','genres','keywords','cast','crew']]
df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# ...

# %%
df['Vector'] = df['overview']+df['tagline']+df['genres']+df['keywords']+df['cast'] +' '+ df['crew']
df.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_28352/629935376.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Vector'] = df['overview']+df['tagline']+df['genres']+df['keywords']+df['cast'] +' '+ df['crew']
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# ...

# %%
df = df[['id','title','Vector']]

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

def stem(text:str)->str:
    x =[]
    for i in text.split():
        x.append(ps.stem(i))
    return ' '.join(x)

# %%
df.Vector = df.Vector.apply(stem)
df.head(2)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#       id                                     title  \
# 0  19995                                    Avatar
# 1    285  Pirates of the Caribbean: At World's End
#
#                                               Vector
# 0  in the 22nd century, a parapleg marin is dispa...
# 1  captain barbossa, long believ to be dead, ha c...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')
vector = cv.fit_transform(df.Vector)
vector = vector.toarray()
vector.shape
# Out:
# (4803, 5000)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(vector)
similarity
# Out:
# array([[1.        , 0.08193419, 0.03419928, ..., 0.06077371, 0.        ,
#         0.        ],
#        [0.08193419, 1.        , 0.04259177, ..., 0.05676567, 0.01962294,
#         0.01844278],
#        [0.03419928, 0.04259177, 1.        , ..., 0.01974496, 0.04095301,
#         0.        ],
#        ...,
#        [0.06077371, 0.05676567, 0.01974496, ..., 1.        , 0.0363877 ,
#         0.01709964],
#        [0.        , 0.01962294, 0.04095301, ..., 0.0363877 , 1.        ,
#         0.08866586],
#        [0.        , 0.01844278, 0.        , ..., 0.01709964, 0.08866586,
#         1.        ]])

# %%
def recommendation(movie:str):
    index = df[df.title == movie].index[0]
    dist = similarity[index]
    l = sorted(list(enumerate(dist)),reverse=True,key=lambda x:x[1])
    for i in l[1:6]:
        # print(df.iloc[i[0]].title)
        print(i)

# %%
recommendation('Batman')
# Out:
# (210, 0.47261170463904445)
# (119, 0.4059316706811661)
# (3, 0.3984095364447978)
# (428, 0.3910309435028875)
# (65, 0.34045882057130067)
